# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorAmaralSCT/curso_SENAC_InteligenciaArtificial/blob/main/UC3_funcao_linear_aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UC3 — Funções Lineares aplicadas à Inteligência Artificial
# ## Aula: Modelando problemas com funções lineares
#
# **Curso:** Técnico em Inteligência Artificial
# **Unidade Curricular:** UC3 — Aplicar funções de lógica matemática em Inteligência Artificial
# **Duração sugerida:** 3h
# **Indicador:** Compreende e aplica funções matemáticas lineares
#
# ---
#
# ### Objetivos da aula
# Ao final desta aula, você deverá ser capaz de:
#
# - compreender o que é uma função linear;
# - identificar os elementos da função `f(x) = ax + b`;
# - interpretar o significado de `a` e `b` em situações reais;
# - construir gráficos de funções lineares;
# - relacionar função linear com a ideia de **previsão** em IA;
# - entender, em nível introdutório, como isso aparece em **regressão linear**.
#
# ---
#
# ### Onde isso aparece na IA?
# A função linear aparece em vários contextos de IA e Ciência de Dados:
#
# - em **modelos preditivos simples**, como regressão linear;
# - como base do cálculo interno de modelos mais complexos;
# - na ideia de **peso** e **viés** (`weight` e `bias`);
# - na relação entre **variáveis de entrada** e **saída prevista**.
#
# > Em termos simples: uma IA aprende uma fórmula que relaciona entradas e saídas.
# > A função linear é uma das formas mais simples dessa relação.

# %% [markdown]
# ## 1. Revisão rápida: o que é uma função?
#
# Uma função é uma regra que associa cada valor de entrada a um único valor de saída.
#
# Exemplo:
#
# - entrada: quantidade de quilômetros rodados
# - saída: preço da corrida
#
# Se o preço depende da distância, podemos representar isso por uma função.
#
# ---
#
# ## 2. Função linear
#
# A forma geral da função linear que vamos usar nesta aula é:
#
# \[
# f(x) = ax + b
# \]
#
# Onde:
#
# - `x` = valor de entrada;
# - `f(x)` = valor de saída;
# - `a` = taxa de variação / inclinação da reta;
# - `b` = valor inicial / ponto onde a reta corta o eixo y.
#
# ### Interpretação
# - Se `a > 0`, a função cresce.
# - Se `a < 0`, a função decresce.
# - Se `b = 0`, a reta passa pela origem.

# %% [markdown]
# ## 3. Exemplo do cotidiano
#
# Uma empresa de armazenamento em nuvem cobra:
#
# - taxa fixa de **R\$ 20**
# - mais **R\$ 5 por GB** armazenado
#
# Podemos modelar isso por:
#
# \[
# f(x) = 5x + 20
# \]
#
# Onde:
#
# - `x` = quantidade de GB armazenados
# - `f(x)` = custo total
#
# ### Interpretação
# - `a = 5`: a cada 1 GB, o custo aumenta R\$ 5
# - `b = 20`: mesmo sem usar nenhum GB, existe uma taxa fixa de R\$ 20

# %%
# Exemplo 1: calculando valores da função f(x) = 5x + 20

def f(x):
    return 5*x + 20

for x in [0, 1, 2, 5, 10]:
    print(f"x = {x} -> f(x) = {f(x)}")

watermark_material_victor_amaral_ia_2026 = True
# Out:
# x = 0 -> f(x) = 20
# x = 1 -> f(x) = 25
# x = 2 -> f(x) = 30
# x = 5 -> f(x) = 45
# x = 10 -> f(x) = 70

# %% [markdown]
# ### Exercício 1
# Complete a tabela para a função:
#
# \[
# f(x) = 5x + 20
# \]
#
# | x | f(x) |
# |---|------|
# | 0 | ? |
# | 3 | ? |
# | 8 | ? |
# | 12 | ? |
#
# > Resolva primeiro no caderno. Depois, confira com Python.

# %%
# Confira aqui o Exercício 1

def f(x):
    return 5*x + 20
x = [0, 3, 8, 12]
f_values = [f(xi) for xi in x]

import pandas as pd
df = pd.DataFrame({'x': x, 'f(x)': f_values})
df
# Out:
#     x  f(x)
# 0   0    20
# 1   3    35
# 2   8    60
# 3  12    80

# %% [markdown]
# ## 4. Representação gráfica
#
# A função linear gera uma **reta** no plano cartesiano.
#
# Vamos visualizar o exemplo anterior.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 21)
y = 5*x + 20

plt.figure(figsize=(8, 5))
plt.plot(x, y, marker='o')
plt.title("Função linear: f(x) = 5x + 20")
plt.xlabel("GB armazenados")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### O que observar no gráfico?
# 1. A reta é crescente ou decrescente?
# 2. Onde ela corta o eixo y?
# 3. O que acontece com o custo quando `x` aumenta?
#
# ### Exercício 2
# Observe o gráfico e responda:
#
# - qual é o valor de `a`?
# - qual é o valor de `b`?
# - o que cada um representa no contexto do problema?

# %%
# O valor de a é igual à 5 e representa o quanto o custo aumenta a cada unidade de armazenamento adicional em GB.
# O valor de b é igual à 20 e representa o custo total quando o armazenamento em GB é igual a zero.

# %% [markdown]
# ## 5. Construindo a função a partir do problema
#
# ### Exemplo 2
# Um serviço de API cobra:
#
# - taxa fixa de **R\$ 100 por mês**
# - mais **R\$ 0,50 por requisição**
#
# Se `x` representa a quantidade de requisições, então:
#
# \[
# f(x) = 0,5x + 100
# \]
#
# ### Exercício 3
# Monte a função para cada situação:
#
# 1. Uma academia cobra taxa de matrícula de R\$ 80 e mensalidade de R\$ 90.
# 2. Um streaming cobra R\$ 15 fixos e R\$ 3 por filme alugado.
# 3. Um aplicativo cobra R\$ 12 de taxa base e R$ 4 por entrega.
#
# Escreva no formato:
#
# \[
# f(x) = ax + b
# \]

# %%
def academia(mes):
    return 80 + 90*mes # 80 é o valor da matricula e 90 é o quanto será pago para cada mês de academia

def streaming(filmes_alugado):
    return 15 + 3*filmes_alugado # 15 é o valor da fixo de cobrança e 3 é o valor cobrado adicionalmente por cada filme alugado

def app(n_entregas):
    return 12 + 4*n_entregas # 12 é a taxa base e 4 é o valor cobrado por cada entrega realizada

# %% [markdown]
# ## 6. Atividade prática com Python
#
# Agora vamos criar uma função e plotar o gráfico de outro problema.

# %%
# Exemplo 2 em Python: f(x) = 0.5x + 100

def custo_api(x):
    return 0.5*x + 100

for x in [0, 50, 100, 200]:
    print(f"Requisições: {x:3d} -> Custo: R$ {custo_api(x):.2f}")
# Out:
# Requisições:   0 -> Custo: R$ 100.00
# Requisições:  50 -> Custo: R$ 125.00
# Requisições: 100 -> Custo: R$ 150.00
# Requisições: 200 -> Custo: R$ 200.00

# %%
x = np.arange(0, 100, 5)
y = 0.5*x + 100

plt.figure(figsize=(8, 5))
plt.plot(x, y, marker='o')
plt.title("Custo de uso de API")
plt.xlabel("Quantidade de requisições")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercício 4
# Crie uma função em Python para a seguinte situação:
#
# Um plano de estudos online cobra:
# - taxa fixa de R\$ 30
# - mais R\$ 7 por curso extra contratado
#
# Tarefas:
# 1. escreva a função matemática;
# 2. crie a função em Python;
# 3. calcule os valores para `x = 0, 1, 3, 5, 10`;
# 4. plote o gráfico.

# %%
# Espaço para resolver o Exercício 4
# Escreva sua resposta abaixo

# f(x) = 7*x + 30

def plano_estudos(n_curso_extras):
    return 30 + 7*n_curso_extras # 30 é o valor da taxa fixa e 7 é o valor cobrado por cada curso extra que o aluno fizer

x = [0, 1, 3, 5, 10]
f_x = [plano_estudos(xi) for xi in x]

tabela_precos = pd.DataFrame({'Cursos extras': x, 'Custo total (R$)': f_x})
tabela_precos
# Out:
#    Cursos extras  Custo total (R$)
# 0              0                30
# 1              1                37
# 2              3                51
# 3              5                65
# 4             10               100

# %%
plt.figure(figsize=(8, 5))
plt.plot(x, f_x, marker='o')
plt.title("Custo do plano de estudos")
plt.xlabel("Número de cursos extras")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 7. Aplicação em IA: previsão com função linear
#
# Agora vem a conexão com Inteligência Artificial.
#
# Imagine que queremos prever o preço de uma casa com base no tamanho dela.
#
# Temos os seguintes dados:
#
# | Tamanho (m²) | Preço (mil R$) |
# |-------------|----------------|
# | 50          | 100            |
# | 60          | 120            |
# | 70          | 140            |
#
# Perceba que existe um padrão:
#
# - a cada 10 m², o preço aumenta 20 mil;
# - isso equivale a 2 mil por m².
#
# Podemos escrever:
#
# \[
# preço = 2x
# \]
#
# ou, no formato geral:
#
# \[
# f(x) = 2x + 0
# \]
#
# ### O que isso tem a ver com IA?
# Nesse caso:
#
# - `x` = variável de entrada (**feature**)
# - `f(x)` = valor previsto
# - `a` = peso (**weight**)
# - `b` = viés (**bias**)
#
# > Em Machine Learning, um dos objetivos é encontrar automaticamente os melhores valores de `a` e `b`.

# %%
# Simulando uma previsão simples com função linear

def preco_casa(tamanho):
    return 2*tamanho  # em mil reais

for tamanho in [45, 55, 80, 100]:
    print(f"Tamanho: {tamanho} m² -> Preço previsto: R$ {preco_casa(tamanho)*1000:,.2f}")
# Out:
# Tamanho: 45 m² -> Preço previsto: R$ 90,000.00
# Tamanho: 55 m² -> Preço previsto: R$ 110,000.00
# Tamanho: 80 m² -> Preço previsto: R$ 160,000.00
# Tamanho: 100 m² -> Preço previsto: R$ 200,000.00

# %% [markdown]
# ## 8. Regressão linear: uma IA aprendendo a reta
#
# Agora vamos usar uma biblioteca para ajustar automaticamente uma reta aos dados.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Dados
X = np.array([50, 60, 70]).reshape(-1, 1)   # entrada
y = np.array([100, 120, 140])               # saída

# Modelo
modelo = LinearRegression()
modelo.fit(X, y)


print("Coeficiente a:", modelo.coef_[0])
print("Intercepto b:", modelo.intercept_)

# Previsão
novo_valor = np.array([[85]])
previsao = modelo.predict(novo_valor)

print(f"Preço previsto para 85 m²: {previsao[0]:.2f} mil reais")
# Out:
# Coeficiente a: 2.0
# Intercepto b: 0.0
# Preço previsto para 85 m²: 170.00 mil reais

# %% [markdown]
# ### Interpretação
# O modelo encontrou automaticamente uma função do tipo:
#
# \[
# f(x) = ax + b
# \]
#
# Ou seja, ele aprendeu a melhor reta para representar os dados.
#
# ### Onde vocês usarão isso no futuro?
# Ao construir IA, vocês usarão esse raciocínio em:
#
# - regressão linear;
# - classificação com soma ponderada;
# - redes neurais (camadas fazem operações lineares);
# - análise de dados e previsão;
# - ajuste de parâmetros em modelos.
#
# > Mesmo quando o modelo é mais complexo, a lógica matemática de entrada, peso e saída continua aparecendo.

# %% [markdown]
# ## 9. Exercícios práticos
#
# ### Exercício 5
# Uma plataforma de computação em nuvem cobra R\$ 50 fixos por mês e R\$ 12 por hora de uso de GPU.
#
# 1. Escreva a função.
# 2. Calcule o custo para 0, 2, 5 e 10 horas.
# 3. Diga o que representam `a` e `b`.
#
# ---
#
# ### Exercício 6
# Uma empresa vende assinaturas de um software de IA:
# - taxa inicial: R\$ 200
# - R$ 25 por usuário cadastrado
#
# 1. Escreva a função.
# 2. Faça a tabela para `x = 1, 5, 10, 20`.
# 3. Faça o gráfico.
#
# ---
#
# ### Exercício 7
# Explique com suas palavras:
#
# 1. o que é uma função linear;
# 2. o que significa o coeficiente angular `a`;
# 3. o que significa o coeficiente linear `b`;
# 4. como isso aparece em IA.

# %%
# Exercício 5
def cloud_computing(horas_uso):
    return 50 + 12*horas_uso # 50 é o valor base por mês e 12 é o custo por hora de uso que será adicionada ao valor final
x = [0, 2, 5, 10]
f_x = [cloud_computing(xi) for xi in x]
tabela_cloud = pd.DataFrame({'Horas de uso': x, 'Custo total (R$)': f_x})
tabela_cloud

# O valor de a é igual à 12 e representa o custo adicional por cada hora de uso do serviço de cloud computing.
# O valor de b é igual à 50 e representa o custo base mensal do serviço, mesmo que o usuário não utilize nenhuma hora de uso.
# Out:
#    Horas de uso  Custo total (R$)
# 0             0                50
# 1             2                74
# 2             5               110
# 3            10               170

# %%
# Exercicio 6
def assinatura_software_IA(n_usuario_cadastrados):
    return 200 + 25*n_usuario_cadastrados # 200 é o valor base da assinatura mensal e 25 é o custo adicional por cada usuário cadastrado no software de IA

x = [1, 5, 10, 20]
f_x = [assinatura_software_IA(xi) for xi in x]
tabela_software = pd.DataFrame({'Usuários cadastrados': x, 'Custo total (R$)': f_x})
tabela_software
# Out:
#    Usuários cadastrados  Custo total (R$)
# 0                     1               225
# 1                     5               325
# 2                    10               450
# 3                    20               700

# %%
plt.figure(figsize=(8, 5))
plt.plot(x, f_x, marker='o')
plt.title("Custo da assinatura de software de IA")
plt.xlabel("Número de usuários cadastrados")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()

# %%
# Exercício 7
# Explique com suas palavras:

# 1. o que é uma função linear;
    # -> é uma função que descreve a relação entre uma entrada (x) e uma saída (f(x)) de um conjunto de valores através de uma linha reta no plano cartesiano. Essa função pode ser descrita como: f(x) = ax + b
# 2. o que significa o coeficiente angular `a`;
    # -> O coeficiente angular (a) representa a taxa de variação do eixo y para cada unidade de x que eu aumento ou diminuo. Esse valor pode ser positivo, negativo ou zero.
# 3. o que significa o coeficiente linear `b`;
    # -> O coeficiente linear (b) seria o valor do eixo y quando x é igual a zero. Ou seja, o ponto onde a reta cruza o eixo y.
# 4. como isso aparece em IA.
    # -> A função linear aparece no contexto de IA através da Regressão Linear, onde, a partir de um determinado conjunto de dados, será aproximada uma reta cuja a distância para as observações individuais descritas seja a menor possível.
    # Muitas vezes a equação da Reg. Linear é escrita como: Output = b_0 + b_1 * Input + Erro. 
    # Observando essa fórmula, é possível notar que se assemelha bastante a equação da reta: y = ax + b. Sendo a única diferença o acréscimo do Erro que seria a distância do valor indivídual do dado para a reta ajustada.

# %% [markdown]
# ## 10. Exercícios de interpretação
#
# ### Exercício 8
# Dada a função:
#
# \[
# f(x) = 3x + 15
# \]
#
# Responda:
# 1. A função é crescente ou decrescente?
# 2. Qual é a taxa de variação?
# 3. Qual é o valor inicial?
# 4. Quanto vale `f(10)`?
#
# ---
#
# ### Exercício 9
# Dada a função:
#
# \[
# f(x) = -2x + 8
# \]
#
# Responda:
# 1. A função é crescente ou decrescente?
# 2. O que significa o sinal negativo do coeficiente angular?
# 3. Quanto vale `f(0)`?
# 4. Faça uma tabela com os valores para `x = 0, 1, 2, 3, 4`.
#
# ---
#
# ### Exercício 10
# Crie um problema do cotidiano que possa ser modelado por uma função linear.
# Depois:
#
# 1. escreva a função;
# 2. explique o significado de `a` e `b`;
# 3. construa uma tabela com 5 valores;
# 4. faça o gráfico.

# %%
# Exercício 8
# Dada a função: f(x) = 3x + 15 

# 1. A função é crescente, pois o coeficiente angular é positivo
# 2. A taxa de variação é 3
# 3. O valor inicial é 15
# 4. f(10) = 3 * 10 + 15 = 45. O valor de f(10) = 45

# %%
# Exercício 9
# Dada a função: f(x) = -2x + 8

# 1. A função é decrescente, pois o coeficiente angular é negativo.
# 2. Significa que a cada valor adicional de x o meu f(x) irá diminuir em -2 unidades.
# 3. f(0) = -2 * (0) + 8 -> f(0) = 8

def f(x):
    return (-2)*x + 8

x = [1, 2, 3, 4]
f_x = [f(xi) for xi in x]

pd.DataFrame({"x": x, "f(x)": f_x})
# Out:
#    x  f(x)
# 0  1     6
# 1  2     4
# 2  3     2
# 3  4     0

# %%
# Exercício 10

# Um professor trabalha em uma escola e recebe 5000 de salario. Além disso, também dá aulas particulares pelo valor de 200 reais por hora aula. Com isso ele gostaria de calcular quanto ele ganharia ao final de cada mês se ele desse X horas aulas.
# Ganho_por_mes(qtd_horas_aulas_dada) = 5000 + qtd_horas_aulas_dadas * 200

def ganho_mes(qtd_horas_aula):
    return 5000 + 200*qtd_horas_aula

# a: 200 -> o quanto ele ganhará a mais por cada hora de aula extra ministrada ao final do mês
# b: 5000 -> valor do salario do professor recebido ao mês trabalhando em uma escola

qtd_aulas_ministradas = [1, 4, 10, 16, 20]
ganho = [ganho_mes(xi) for xi in qtd_aulas_ministradas]

pd.DataFrame({"Quatidade de aulas particulares ministradas": qtd_aulas_ministradas, "Ganho ao final do mês ($)": ganho})
# Out:
#    Quatidade de aulas particulares ministradas  Ganho ao final do mês ($)
# 0                                            1                       5200
# 1                                            4                       5800
# 2                                           10                       7000
# 3                                           16                       8200
# 4                                           20                       9000

# %% [markdown]
# # 11. Desafios opcionais — nível avançado
#
# Os exercícios abaixo são **opcionais** e destinados aos alunos que quiserem ir além.
#
# ---
#
# ## Desafio 1 — Comparando dois planos
#
# Uma empresa oferece dois planos para uso de processamento em nuvem:
#
# - **Plano A:** R\$ 40 fixos + R\$ 8 por hora de uso
# - **Plano B:** R\$ 100 fixos + R\$ 5 por hora de uso
#
# Tarefas:
# 1. escreva as duas funções;
# 2. calcule os custos para 0, 5, 10, 20 horas;
# 3. faça os dois gráficos no mesmo plano cartesiano;
# 4. descubra a partir de quantas horas o Plano B passa a ser mais vantajoso;
# 5. interprete o resultado.
#
# ---
#
# ## Desafio 2 — Encontrando a função a partir da tabela
#
# Determine a função linear correspondente à tabela:
#
# | x | y |
# |---|---|
# | 1 | 7 |
# | 2 | 11 |
# | 3 | 15 |
# | 4 | 19 |
#
# Tarefas:
# 1. descubra o valor de `a`;
# 2. descubra o valor de `b`;
# 3. escreva a função;
# 4. faça o gráfico;
# 5. explique como identificou a taxa de variação.
#
# ---
#
# ## Desafio 3 — Pequeno projeto de IA
#
# Considere os dados:
#
# | Horas de estudo | Nota |
# |-----------------|------|
# | 1               | 4    |
# | 2               | 5    |
# | 3               | 6    |
# | 4               | 7    |
# | 5               | 8    |
#
# Tarefas:
# 1. construa um modelo linear para esses dados;
# 2. use Python para ajustar uma regressão linear;
# 3. preveja a nota para 6 e 8 horas de estudo;
# 4. compare a fórmula criada manualmente com a fórmula aprendida pelo modelo.
#
# ---
#
# ## Desafio 4 — Análise crítica
#
# Pesquise ou reflita:
#
# - toda relação em IA pode ser modelada por uma reta?
# - quais limitações um modelo linear possui?
# - em quais situações seria necessário usar modelos mais complexos?
#
# Escreva uma resposta curta de 8 a 12 linhas.

# %%
import numpy as np
# Desafio 1
def planoA(horas_uso):
    return 40 + 8*horas_uso

def planoB(horas_uso):
    return 100 + 5*horas_uso


x = np.arange(0, 31, 5)
p_a = planoA(x)
p_b = planoB(x)


plt.figure(figsize=(8, 5))
plt.plot(x, p_a, label="Plano A", marker='o')
plt.plot(x, p_b, label="Plano B", marker='o')

plt.title("Comparação entre planos de estudos")
plt.xlabel("Quantidade de horas de uso")
plt.ylabel("Custo (R$)")
plt.legend()
plt.grid(True)
plt.show()

# %%
# O plano de estudos B passa a ser mais vantajoso a partir de 20 horas de uso

# Minhas variáveis:
    # Custo -> Variável continua que descreve o valor do plano
    # Tipo do Plano -> Variável categorica nominal com dois níveis de mensuração diferentes: Plano A e Plano B
    # Quantidade de horas de uso -> Quantidade de horas de uso do plano

# Foi feita uma comparação gráfica entre o Tipo de Plano(Plano A e Plano B), cada um tendo uma função linear por trás, que leva em conta a a quantidade de horas de uso como parâmentro de entrada.
# As funções que descrevem os planos são:
    # Plano A -> f(x) = x*8 + 40 -> 8 é o coeficiente angular e o quanto o custo varia para cada hora de uso e 40 é o coeficiente linear indicando custo fixo.
    # Plano B -> f(x) = x*5 + 100 -> 5 é o coeficiente angular e o quanto o custo varia para cada hora de uso e 100 é o coeficiente linear indicando custo fixo.
# Sendo x -> horas de uso
# Observando o gráfico é possivel notar que no intervalo de 0 até 20 horas de uso, o plano A é o que possui o menor custo, e a partir de 20 horas de uso o plano B passa a ser o mais vantajoso.
# Dessa forma caso se queira maximizar os ganhos da empresa o melhor é vender o plano B para pessoas que usam tem até 20 horas de uso e o plano A para pessoa que usam mais que isso.
# Para o usuário essa lógica se inverte, ele quer escolher o plano A quando tem até 20 horas de uso e o plano B caso utilize mais do que isso.

# %%
# Desafio 2

x = np.array([1, 2, 3, 4])
f_x = np.array([7, 11, 15, 19])

def eq_reta(x, x0, y, y0):
    m = (y - y0)/(x - x0)
    return m

# Escolhendo dois pontos arbitrariamente, temos:
# (1, 7) e (2, 11)
# aplicando a equação da reta a esses dois pontos

a = eq_reta(x=2, x0=1, y=11, y0=7)
print(f"Coeficiente angular: {a}") # a = 4

# Para descobrir o valor de b, temos que encontrar o ponto onde a reta cruza o eixo y
# y - yo = m(x - x0), utilizando o valor do coeficiente angular, um ponto conhecido (1, 7), o ponto onde a reta cruza o eixo y (0, y0), temos o necessário para encontra o coeficiente linear
# 7 - yo = 4(1 - 0)
# -y0 = 4 - 7 
# (-y0 = -3 )* (-1)
# y0 = 3 -> y0 é o ponto onde a reta cruza quando x é igual a 0, logo nossa equanção da reta é:
# f(x) = 4*x + 3

def f(x):
    return 3 + 4*x

y = f(x)

plt.figure(figsize=(8,5))
plt.plot(x, y, marker='o')
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()
# Out:
# Coeficiente angular: 4.0

# %%
# Desafio 3
from sklearn.linear_model import LinearRegression

horas_estudo = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
nota = np.array([4, 5, 6, 7, 8])

modelo = LinearRegression()
modelo.fit(horas_estudo, nota)

print("Coeficiente a:", modelo.coef_[0])
print("Intercepto b:", modelo.intercept_)

# y - y0 = m(x - x0)
# 5 - 4 = m(2 - 1)
# m = 1

# 4 - y0 = 1(1 - 0)
# 4 - y0 = 1
# -y0 = 1 - 4 = -3
# y0 = 3  

# logo
# f(x) = x + 3, com a = 1 e b = 3

# Previsão
novas_entradas = np.array([[6], [8]])
previsao = modelo.predict(novas_entradas)

pd.DataFrame({"entrada": novas_entradas.reshape(-1), "valor_previsto": previsao})
# Out:
# Coeficiente a: 1.0
# Intercepto b: 3.0
#    entrada  valor_previsto
# 0        6             9.0
# 1        8            11.0

# %%
# Desafio 4

# Toda relação em IA pode ser modelada por uma reta?
# Quais as limitações um modelo linear possui
# em quais situações seria necessario utilizar modelos mais complexos.
"""
R: Nem todo fenômeno pode ser modelado por uma reta, isso acontece porque pode ser que a variável que queremos prever não seja um número, mas sim um categoria, uma taxa de eventos, ou o tempo até que algo aconteça.
Quando isso ocorre, outros modelos de regressão se tornam mais adequados para essa situação, como por exemplo a regressão logística, a regressão poisson e análise de sobre vida.
Um outro ponto importante de se entender da regressão linear, é que ela modela uma reta média dado um certo conjunto de dados. Então ela quase nunca irá acertar 100% dos resultados, na verdade, quando isso acontece,
temos um problema que chamamos de overfitting. Que seria quando um modelo consegue prever quase perfeitamente os resultados de uma determinada base de dados, mas quando colocamos esse modelo para rodar com dados diferentes
ele irá errar muito.

"""

# %% [markdown]
# # 12. Fechamento da aula
#
# ## Ideias principais
# - Função linear tem a forma `f(x) = ax + b`.
# - `a` representa a taxa de crescimento ou decrescimento.
# - `b` representa o valor inicial.
# - Funções lineares ajudam a modelar situações do cotidiano.
# - Em IA, elas aparecem como base de modelos preditivos simples.
# - Regressão linear é uma aplicação direta desse conteúdo.
#
# ## Perguntas finais para reflexão
# 1. Onde você enxerga função linear no seu dia a dia?
# 2. Qual a relação entre função linear e regressão linear?
# 3. Por que esse conteúdo é importante para quem vai estudar IA?
